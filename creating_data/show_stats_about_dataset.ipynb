# %%
import pandas as pd
import zipfile
from pathlib import Path
import json
pd.set_option('display.max_rows', 50)
pd.options.display.float_format = '{:,.2f}'.format

# %%
DF_INDEX_ZIP_FILE_PATH = Path("index.zip")
DF_INDEX_CSV_FILE_PATH = Path("index.csv")
MITRE_LABELS_JSON_PATH = Path("MITRE_labels.json")

# %%
with zipfile.ZipFile(DF_INDEX_ZIP_FILE_PATH, 'r') as zip_ref:
    zip_ref.extractall(DF_INDEX_CSV_FILE_PATH.parent)

# %%
index_df = pd.read_csv(DF_INDEX_CSV_FILE_PATH)
index_df
# Out:
#         Unnamed: 0                                git_repo  year  \
# 0                0  APT_CyberCriminal_Campagin_Collections  2018
# 1                1  APT_CyberCriminal_Campagin_Collections  2018
# 2                2  APT_CyberCriminal_Campagin_Collections  2018
# 3                3  APT_CyberCriminal_Campagin_Collections  2018
# 4                4  APT_CyberCriminal_Campagin_Collections  2018
# ...            ...                                     ...   ...
# 657719      657719  APT_CyberCriminal_Campagin_Collections  2008
# 657720      657720  APT_CyberCriminal_Campagin_Collections  2008
# 657721      657721  APT_CyberCriminal_Campagin_Collections  2008
# 657722      657722  APT_CyberCriminal_Campagin_Collections  2008
# 657723      657723  APT_CyberCriminal_Campagin_Collections  2008
#
#                                                filename group_name  \
# 0       MuddyWater_Middle_East_and_Central_Asia.pdf.txt         []
# 1       MuddyWater_Middle_East_and_Central_Asia.pdf.txt         []
# 2       MuddyWater_Middle_East_and_Central_Asia.pdf.txt         []
# 3       MuddyWater_Middle_East_and_Central_Asia.pdf.txt         []
# 4       MuddyWater_Middle_East_and_Central_Asia.pdf.txt         []
# ...                                                 ...        ...
# 657719                          army-bans-usb-d.pdf.txt         []
# 657720                          army-bans-usb-d.pdf.txt         []
# 657721                          army-bans-usb-d.pdf.txt         []
# 657722                          army-bans-usb-d.pdf.txt         []
# 657723                          army-bans-usb-d.pdf.txt         []
#
#        software_name technique_name tactic
# 0                 []             []     []
# 1                 []             []     []
# 2                 []             []     []
# 3                 []             []     []
# 4                 []             []     []
# ...              ...            ...    ...
# 657719            []             []     []
# 657720            []             []     []
# 657721            []             []     []
# 657722            []             []     []
# 657723            []             []     []
#
# [657724 rows x 8 columns]

# %%
labels = ["group_name", "software_name", "technique_name", "tactic"]
print(f"Total lines {len(index_df)}")
for label in labels:
    print(f"lines with {label}: {len(index_df[index_df[label] != str([])])}")
# Out:
# Total lines 657724
# lines with group_name: 11132
# lines with software_name: 16492
# lines with technique_name: 8132
# lines with tactic: 8474

# %%
year_df = pd.DataFrame()

year_df["year"]= index_df["year"].value_counts(sort=True).sort_index().index
year_df["count"] = index_df["year"].value_counts(sort=True).sort_index().values
year_df["%"] = index_df["year"].value_counts(sort=True, normalize=True).sort_index().values


year_df
# Out:
#     year  count    %
# 0   2006    251 0.00
# 1   2008   4725 0.01
# 2   2009   5916 0.01
# 3   2010  10706 0.02
# 4   2011   7948 0.01
# 5   2012  17644 0.03
# 6   2013  58956 0.09
# 7   2014  72915 0.11
# 8   2015  74365 0.11
# 9   2016  94384 0.14
# 10  2017  56511 0.09
# 11  2018  64705 0.10
# 12  2019  83372 0.13
# 13  2020  95952 0.15
# 14  2021   9374 0.01

# %%
verbose_index_df = index_df.copy()

with Path(MITRE_LABELS_JSON_PATH).open("r", encoding="utf8") as f:
    mitre_labels = json.load(f)
    
def check_if_label_exists(label, line):
    if label in line:
        return True
    return False

values_list = []
for key in mitre_labels:
    for label_value in mitre_labels[key]:
        values_list.append(label_value)
        verbose_index_df[label_value] = index_df[key].str.contains(label_value)

verbose_index_df
# Out:
#         Unnamed: 0                                git_repo  year  \
# 0                0  APT_CyberCriminal_Campagin_Collections  2018
# 1                1  APT_CyberCriminal_Campagin_Collections  2018
# 2                2  APT_CyberCriminal_Campagin_Collections  2018
# 3                3  APT_CyberCriminal_Campagin_Collections  2018
# 4                4  APT_CyberCriminal_Campagin_Collections  2018
# ...            ...                                     ...   ...
# 657719      657719  APT_CyberCriminal_Campagin_Collections  2008
# 657720      657720  APT_CyberCriminal_Campagin_Collections  2008
# 657721      657721  APT_CyberCriminal_Campagin_Collections  2008
# 657722      657722  APT_CyberCriminal_Campagin_Collections  2008
# 657723      657723  APT_CyberCriminal_Campagin_Collections  2008
#
#                                                filename group_name  \
# 0       MuddyWater_Middle_East_and_Central_Asia.pdf.txt         []
# 1       MuddyWater_Middle_East_and_Central_Asia.pdf.txt         []
# 2       MuddyWater_Middle_East_and_Central_Asia.pdf.txt         []
# 3       MuddyWater_Middle_East_and_Central_Asia.pdf.txt         []
# 4       MuddyWater_Middle_East_and_Central_Asia.pdf.txt         []
# ...                                                 ...        ...
# 657719                          army-bans-usb-d.pdf.txt         []
# 657720                          army-bans-usb-d.pdf.txt         []
# 657721                          army-bans-usb-d.pdf.txt         []
# 657722                          army-bans-usb-d.pdf.txt         []
# 657723                          army-bans-usb-d.pdf.txt         []
#
#        software_name technique_name tactic  Energetic Bear  Chinastrats  ...  \
# 0                 []             []     []           False        False  ...
# 1                 []             []     []           False        False  ...
# 2                 []             []     []           False        False  ...
# 3                 []             []     []           False        False  ...
# 4                 []             []     []           False        False  ...
# ...              ...            ...    ...             ...          ...  ...
# 657719            []             []     []           False        False  ...
# 657720            []             []     []           False        False  ...
# 657721            []             []     []           False        False  ...
# 657722            []             []     []           False        False  ...
# 657723            []             []     []           False        False  ...
#
#         Defense Evasion  Collection  Credential Access  Execution  \
# 0                 False       False              False      False
# 1                 False       False              False      False
# 2                 False       False              False      False
# 3                 False       False              False      False
# 4                 False       False              False      False
# ...                 ...         ...                ...        ...
# 657719            False       False              False      False
# 657720            False       False              False      False
# 657721            False       False              False      False
# 657722            False       False              False      False
# 657723            False       False              False      False
#
#         Lateral Movement  Discovery  Command and Control  Persistence  \
# 0                  False      False                False        False
# 1                  False      False                False        False
# 2                  False      False                False        False
# 3                  False      False                False        False
# 4                  False      False                False        False
# ...                  ...        ...                  ...          ...
# 657719             False      False                False        False
# 657720             False      False                False        False
# 657721             False      False                False        False
# 657722             False      False                False        False
# 657723             False      False                False        False
#
#         Exfiltration  Privilege Escalation
# 0              False                 False
# 1              False                 False
# 2              False                 False
# 3              False                 False
# 4              False                 False
# ...              ...                   ...
# 657719         False                 False
# 657720         False                 False
# 657721         False                 False
# 657722         False                 False
# 657723         False                 False
#
# [657724 rows x 476 columns]

# %%
print("verbose_index_df.shape", verbose_index_df.shape)

value_counter = dict()
for label_value in values_list:
    value_counter[label_value] = [verbose_index_df[label_value].sum()]

with pd.option_context('display.max_rows', 500, 'display.max_columns', 10):
    display(pd.DataFrame(value_counter).transpose())
# Out:
# verbose_index_df.shape (657724, 476)
#                                                        0
# Energetic Bear                                        49
# Chinastrats                                            4
# Gamaredon Group                                       76
# HIDDEN COBRA                                          34
# MONSOON                                               79
# Fancy Bear                                            57
# Stone Panda                                           21
# Buckeye                                               70
# Threat Group-1314                                      0
# Poseidon Group                                        20
# WebMasters                                             5
# Equation                                             239
# Threat Group-3390                                      6
# Molerats                                              50
# Lotus Blossom                                        113
# Deputy Dog                                             9
# GCMAN                                                  7
# Carbanak                                               0
# Deep Panda                                            76
# DragonOK                                              77
# Strider                                               19
# Shell Crew                                             5
# PittyTiger                                            47
# OilRig                                               135
# IXESHE                                               129
# CVNX                                                   8
# ProjectSauron                                          0
# APT10                                                444
# Emissary Panda                                        51
# MSUpdater                                              7
# APT17                                                 47
# Blackfly                                              11
# TG-3390                                              183
# Turla                                                963
# The Dukes                                             97
# Winnti Group                                         151
# FIN7                                                 203
# Moafee                                                33
# APT3                                                 515
# Night Dragon                                          97
# APT16                                                 14
# KungFu Kittens                                         5
# Black Vine                                           107
# APT32                                                118
# OceanLotus Group                                      14
# Dropping Elephant                                     31
# TG-2889                                                6
# Guardians of Peace                                    11
# RTM                                                    0
# APT1                                                1151
# Putter Panda                                          20
# Group5                                               162
# STRONTIUM                                             14
# Red Apollo                                             7
# APT2                                                 588
# Comment Group                                          5
# Dynamite Panda                                         3
# Quedagh                                               33
# Darkhotel                                             61
# admin@338                                             71
# Numbered Panda                                        27
# Operation Molerats                                     5
# Taidoor                                              234
# Naikon                                               339
# Cleaver                                              121
# Threat Group-0416                                      0
# Comment Panda                                          4
# FIN6                                                  44
# menuPass                                             124
# UPS Team                                               3
# Axiom                                                105
# Cozy Bear                                             27
# Pirpi                                                  0
# Ke3chang                                             174
# Scarlet Mimic                                         76
# FIN10                                                  4
# Threat Group-0110                                      1
# Dragonfly                                            123
# Dust Storm                                            15
# Operation Hangover                                   180
# Gothic Panda                                           8
# TG-4127                                                2
# Sandworm Team                                         22
# TG-0110                                                5
# PinkPanther                                            3
# DynCalc                                               12
# Waterbug                                             210
# Sednit                                               465
# Tsar Team                                             12
# APT18                                                 32
# Gaza cybergang                                        25
# APT12                                                 68
# APT29                                                130
# Pawn Storm                                           204
# Stealth Falcon                                        21
# TG-1314                                                0
# Spring Dragon                                          8
# Anunak                                                 0
# APT30                                                209
# Suckfly                                               26
# Patchwork                                            148
# Threat Group 2889                                      1
# Threat Group-4127                                      1
# Lazarus Group                                        379
# Comment Crew                                          62
# Sofacy                                               341
# Group 72                                              24
# APT28                                                468
# BRONZE UNION                                          43
# TG-0416                                                2
# HammerDuke                                            31
# nbtstat.exe                                            0
# NeD Worm                                              18
# XTunnel                                                2
# Sys10                                                 11
# hcdLoader                                              1
# Enfal                                                 46
# ELMER                                                 14
# MiniDuke                                             268
# MobileOrder                                           14
# systeminfo.exe                                         9
# Ixeshe                                                 0
# Arp                                                    0
# Windows Credential Editor                             15
# netsh                                                 56
# cmd.exe                                              610
# SPACESHIP                                             45
# TinyZBot                                              64
# OwaAuth                                               16
# Lecna                                                  6
# Derusbi                                              254
# arp.exe                                                0
# HAMMERTOSS                                            76
# WinMM                                                 16
# CORESHELL                                             54
# HDoor                                                 10
# Komplex                                               65
# gh0st                                                 75
# Win32/USBStealer                                       0
# PowerDuke                                              7
# Trojan.GTALK                                           0
# CHOPSTICK                                             82
# Pisloader                                              2
# Custom HDoor                                           5
# HIDEDRV                                               23
# CozyDuke                                             218
# PinchDuke                                             67
# Psylo                                                 22
# Misdat                                                24
# xCmd                                                   0
# EvilGrab                                              57
# SOURFACE                                              55
# GLOOXMAIL                                              3
# PsExec                                               100
# SNUGRIDE                                               1
# NETUI                                                  4
# SHIPSHAPE                                             41
# USB Stealer                                            0
# VIPER                                                  7
# Sasfis                                                 1
# Remsec                                                40
# ASPXSpy                                               20
# CALENDAR                                               3
# Backdoor.Oldrea                                        0
# BACKSPACE                                            266
# Nidiran                                               16
# Reg                                                   29
# Mivast                                                13
# CozyCar                                               11
# schtasks.exe                                          25
# BISCUIT                                                9
# S-Type                                                 0
# Net                                                  195
# SeaDesk                                                0
# ftp.exe                                                6
# Unknown Logger                                        20
# TEXTMATE                                               1
# Sakula                                               144
# netsh.exe                                              0
# TinyBaron                                              0
# Scorpion                                               8
# ADVSTORESHELL                                          5
# Elise                                                114
# Cachedump                                              1
# Trojan.Karagany                                        0
# Token Control                                          0
# Page                                                1507
# XAgentOSX                                              1
# pwdump                                                16
# POWERSOURCE                                            3
# Epic                                                  67
# BUGJUICE                                               0
# schtasks                                              95
# HALFBAKED                                              4
# Pteranodon                                            15
# Tasklist                                               9
# RIPTIDE                                               30
# RedLeaves                                             40
# NETEAGLE                                              44
# Emissary                                             358
# reg.exe                                                8
# MiniDionis                                            14
# 3PARA RAT                                             18
# httpclient                                             5
# Systeminfo                                             9
# Backdoor.Nidiran                                       0
# OnionDuke                                            119
# CloudLook                                              6
# SOUNDBITE                                              6
# ipconfig.exe                                           7
# nbtstat                                               11
# JHUHUGIT                                              11
# cmd                                                  874
# Backdoor.APT.CookieCutter                              0
# Backdoor.Remsec                                        0
# HTTPBrowser                                           16
# pngdowner                                              7
# Uroburos                                             145
# StreamEx                                               2
# BLACKCOFFEE                                           13
# WCE                                                   28
# USBStealer                                             7
# SPLM                                                  61
# netstat                                               82
# SeaDaddy                                               7
# NetC                                                   4
# KOMPROGO                                               7
# Lurid                                                 34
# BUBBLEWRAP                                             6
# WINDSHIELD                                            16
# PoisonIvy                                             59
# ping.exe                                               8
# Poison Ivy                                           473
# HttpDump                                               6
# PlugX                                                773
# Kaba                                                  20
# SslMM                                                 13
# Winnti                                               693
# HAYMAKER                                               0
# Seduploader                                           97
# CosmicDuke                                           144
# GeminiDuke                                            41
# ComRAT                                               135
# SeaDuke                                               54
# AutoIt                                                85
# Mis-Type                                               0
# ChChes                                                77
# ZLib                                                   0
# Sogu                                                  21
# ASPXTool                                               4
# LOWBALL                                                9
# DustySky                                              65
# Mimikatz                                             382
# Black Energy                                          10
# FakeM                                                122
# 4H RAT                                                14
# CallMe                                                 9
# China Chopper                                        229
# WEBC2                                                 39
# net.exe                                               22
# POSHSPY                                                2
# FLASHFLOOD                                            40
# XAPS                                                   4
# gsecdump                                              30
# BlackEnergy                                          487
# Ping                                                  32
# Backdoor.APT.FakeWinHTTPHelper                         0
# netstat.exe                                            9
# X-Tunnel                                               0
# RARSTONE                                               5
# Sakurel                                               30
# OLDBAIT                                               11
# SHOTPUT                                                9
# Tavdig                                                35
# CloudDuke                                             89
# Lslsass                                                1
# FTP                                                  332
# ipconfig                                              86
# DNSMessenger                                          13
# Hikit                                                 73
# TINYTYPHON                                            18
# BADNEWS                                               67
# PHOREAL                                                5
# BKDR_ESILE                                             3
# Cobalt Strike                                        666
# Pass-The-Hash Toolkit                                  0
# Net Crawler                                           14
# NetDuke                                                0
# Havex                                                107
# Code Signing                                          82
# Access Token Manipulation                              8
# Re-opened Applications                                 0
# Shortcut Modification                                  7
# Service Registry Permissions Weakness                  0
# Pass the Ticket                                        4
# Input Prompt                                           2
# Execution through Module Load                          8
# Network Sniffing                                       6
# Registry Run Keys / Start Folder                       1
# Pass the Hash                                         15
# Application Shimming                                   2
# Office Application Startup                             5
# File System Permissions Weakness                       0
# Clear Command History                                  4
# Windows Management Instrumentation Event Subscr...     1
# Connection Proxy                                      25
# Cron Job                                               0
# Component Firmware                                     4
# Network Share Connection Removal                       0
# Security Support Provider                             13
# Fallback Channels                                     14
# Login Item                                             3
# Masquerading                                          49
# Obfuscated Files or Information                       31
# Commonly Used Port                                    29
# Netsh Helper DLL                                       2
# System Time Discovery                                 12
# Remote File Copy                                      27
# Screen Capture                                        35
# Hypervisor                                             8
# Remote System Discovery                                8
# Sudo                                                   2
# Standard Application Layer Protocol                   15
# Web Shell                                             76
# Third-party Software                                   0
# Data from Network Shared Drive                         5
# System Network Configuration Discovery                 7
# Video Capture                                          4
# Rc.common                                              1
# .bash_profile and .bashrc                              1
# Data Encrypted                                        30
# Data from Local System                                26
# Windows Admin Shares                                  11
# System Firmware                                        3
# Application Deployment Software                        0
# AppInit DLLs                                           2
# Credentials in Files                                  10
# Multiband Communication                                1
# Brute Force                                           20
# Scripting                                            102
# PowerShell                                          1270
# DLL Injection                                          5
# Custom Command and Control Protocol                    6
# Input Capture                                         31
# File System Logical Offsets                            1
# Scheduled Transfer                                     6
# Exfiltration Over Physical Medium                      0
# Uncommonly Used Port                                  11
# Logon Scripts                                          6
# Bootkit                                               50
# Startup Items                                          3
# File and Directory Discovery                          24
# Exfiltration Over Alternative Protocol                 3
# Hidden Users                                           1
# Remote Desktop Protocol                               46
# Plist Modification                                     3
# Audio Capture                                          9
# Launch Daemon                                          2
# Automated Exfiltration                                10
# Command-Line Interface                                 0
# External Remote Services                              11
# Rundll32                                              37
# Web Service                                           25
# File Deletion                                         36
# DLL Side-Loading                                       0
# NTFS Extended Attributes                               1
# Account Discovery                                     22
# Network Service Scanning                              12
# Gatekeeper Bypass                                      1
# Remote Services                                       45
# Hidden Window                                          7
# Source                                               479
# Replication Through Removable Media                    1
# Hidden Files and Directories                          11
# Trusted Developer Utilities                            2
# Email Collection                                      13
# Exploitation of Vulnerability                          0
# Two-Factor Authentication Interception                 0
# Valid Accounts                                        38
# Timestomp                                             19
# Data Staged                                           21
# System Service Discovery                               9
# Standard Cryptographic Protocol                       12
# New Service                                           24
# Disabling Security Tools                               8
# Rootkit                                              121
# Custom Cryptographic Protocol                          7
# Exfiltration Over Command and Control Channel          4
# LC_MAIN Hijacking                                      1
# Application Window Discovery                           4
# Install Root Certificate                               2
# AppleScript                                            2
# Winlogon Helper DLL                                    2
# Exfiltration Over Other Network Medium                 0
# Indicator Removal from Tools                           5
# LC_LOAD_DYLIB Addition                                 0
# Data from Removable Media                              5
# Service Execution                                     22
# Modify Registry                                       22
# Account Manipulation                                  10
# Communication Through Removable Media                  1
# Security Software Discovery                           12
# Binary Padding                                         9
# Data Compressed                                       18
# Windows Remote Management                              5
# Software Packing                                      17
# Multi-Stage Channels                                   0
# Local Port Monitor                                     0
# Data Encoding                                         28
# DLL Search Order Hijacking                            14
# Create Account                                        10
# Data Transfer Size Limits                              3
# Shared Webroot                                         2
# Component Object Model Hijacking                       1
# InstallUtil                                           17
# System Information Discovery                          27
# Authentication Package                                 3
# Regsvr32                                              11
# Space after Filename                                   2
# Change Default File Association                        3
# Peripheral Device Discovery                            7
# Clipboard Data                                         8
# Launchctl                                              3
# Dylib Hijacking                                        2
# Query Registry                                        21
# System Owner/User Discovery                            0
# Path Interception                                      6
# Process Discovery                                     28
# Standard Non-Application Layer Protocol                0
# Multilayer Encryption                                  7
# Regsvcs/Regasm                                         0
# Launch Agent                                           2
# Permission Groups Discovery                            9
# HISTCONTROL                                            1
# Graphical User Interface                               5
# Scheduled Task                                        77
# Windows Management Instrumentation                    47
# Process Hollowing                                      9
# System Network Connections Discovery                   8
# Accessibility Features                                11
# Modify Existing Service                                3
# Data Obfuscation                                      17
# Automated Collection                                  15
# Securityd Memory                                       1
# Private Keys                                          10
# Deobfuscate/Decode Files or Information                0
# Execution through API                                 19
# Indicator Removal on Host                             23
# Network Share Discovery                               13
# Indicator Blocking                                     3
# Trap                                                  16
# Bypass User Account Control                           12
# Taint Shared Content                                   4
# Keychain                                               1
# Setuid and Setgid                                      2
# Redundant Access                                      11
# Credential Dumping                                    33
# Bash History                                           1
# Defense Evasion                                       50
# Collection                                            98
# Credential Access                                     39
# Execution                                            563
# Lateral Movement                                      99
# Discovery                                            434
# Command and Control                                  451
# Persistence                                          319
# Exfiltration                                         160
# Privilege Escalation                                  89
