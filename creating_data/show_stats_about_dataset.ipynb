# %%
import pandas as pd
import zipfile
from pathlib import Path
import json
pd.set_option('display.max_rows', 50)
pd.options.display.float_format = '{:,.2f}'.format

# %%
DF_INDEX_PATH = Path("index_df.zip")
MITRE_LABELS_JSON_PATH = Path("MITRE_labels.json")

# %%
index_df = pd.read_csv(DF_INDEX_PATH)
print(index_df.shape)
index_df[(index_df.group_name != "[]") & (index_df.software_name != "[]")& (index_df.technique_name != "[]")]
# Out:
# (657724, 8)
#         Unnamed: 0                                git_repo  year  \
# 861            861  APT_CyberCriminal_Campagin_Collections  2018
# 20047        20047  APT_CyberCriminal_Campagin_Collections  2018
# 439827      439827  APT_CyberCriminal_Campagin_Collections  2015
# 626948      626948  APT_CyberCriminal_Campagin_Collections  2019
# 627108      627108  APT_CyberCriminal_Campagin_Collections  2019
# 627154      627154  APT_CyberCriminal_Campagin_Collections  2019
#
#                                                  filename     group_name  \
# 861                           ESET_Turla_Mosquito.pdf.txt      ['turla']
# 20047            ukatemicrysys_territorialdispute.pdf.txt      ['turla']
# 439827  Satellite-turla-apt-command-and-control-in-the...      ['turla']
# 626948                 ESET_Operation_Ghost_Dukes.pdf.txt      ['apt29']
# 627108                 ESET_Operation_Ghost_Dukes.pdf.txt  ['the dukes']
# 627154                 ESET_Operation_Ghost_Dukes.pdf.txt  ['the dukes']
#
#        software_name            technique_name tactic
# 861     ['uroburos']               ['rootkit']     []
# 20047   ['uroburos']               ['rootkit']     []
# 439827  ['uroburos']               ['rootkit']     []
# 626948   ['poshspy']            ['powershell']     []
# 627108    ['psexec']     ['service execution']     []
# 627154    ['psexec']  ['windows admin shares']     []

# %%
labels = ["group_name", "software_name", "technique_name", "tactic"]
print(f"Total lines {len(index_df)}")
for label in labels:
    print(f"lines with {label}: {len(index_df[index_df[label] != str([])])}")
# Out:
# Total lines 657724
# lines with group_name: 11132
# lines with software_name: 16492
# lines with technique_name: 8132
# lines with tactic: 8474

# %%
year_df = pd.DataFrame()

year_df["year"]= index_df["year"].value_counts(sort=True).sort_index().index
year_df["count"] = index_df["year"].value_counts(sort=True).sort_index().values
year_df["%"] = index_df["year"].value_counts(sort=True, normalize=True).sort_index().values


year_df
# Out:
#     year  count    %
# 0   2006    251 0.00
# 1   2008   4725 0.01
# 2   2009   5916 0.01
# 3   2010  10706 0.02
# 4   2011   7948 0.01
# 5   2012  17644 0.03
# 6   2013  58956 0.09
# 7   2014  72915 0.11
# 8   2015  74365 0.11
# 9   2016  94384 0.14
# 10  2017  56511 0.09
# 11  2018  64705 0.10
# 12  2019  83372 0.13
# 13  2020  95952 0.15
# 14  2021   9374 0.01

# %%
# slice into interesting lines only -> than create a column for each name the dataset was labeled by
verbose_index_df = index_df.copy()

verbose_index_df = verbose_index_df[
    (verbose_index_df.group_name != "[]")    |
    (verbose_index_df.software_name != "[]") |
    (index_df.technique_name != "[]")        |
    (index_df.tactic != "[]") 
]
print(f"{verbose_index_df.shape=}")

def load_mitre_labels_lower():
    with Path(MITRE_LABELS_JSON_PATH).open("r", encoding="utf8") as f:
        mitre_labels = json.load(f)
        for entity_type in mitre_labels:
            mitre_labels[entity_type] = [name.lower() for name in mitre_labels[entity_type]]
    return mitre_labels

def check_if_label_exists(label, line):
    if label in line:
        return True
    return False

mitre_labels = load_mitre_labels_lower()
values_list = []
for entity_type in mitre_labels:
    for name in mitre_labels[entity_type]:
        values_list.append(name)
        verbose_index_df[name] = index_df[entity_type].str.contains(name)

verbose_index_df
# Out:
# verbose_index_df.shape=(42393, 8)
#         Unnamed: 0                                git_repo  year  \
# 51              51  APT_CyberCriminal_Campagin_Collections  2018
# 128            128  APT_CyberCriminal_Campagin_Collections  2018
# 131            131  APT_CyberCriminal_Campagin_Collections  2018
# 134            134  APT_CyberCriminal_Campagin_Collections  2018
# 135            135  APT_CyberCriminal_Campagin_Collections  2018
# ...            ...                                     ...   ...
# 657633      657633  APT_CyberCriminal_Campagin_Collections  2008
# 657639      657639  APT_CyberCriminal_Campagin_Collections  2008
# 657665      657665  APT_CyberCriminal_Campagin_Collections  2008
# 657717      657717  APT_CyberCriminal_Campagin_Collections  2008
# 657718      657718  APT_CyberCriminal_Campagin_Collections  2008
#
#                                                filename group_name  \
# 51      MuddyWater_Middle_East_and_Central_Asia.pdf.txt         []
# 128     MuddyWater_Middle_East_and_Central_Asia.pdf.txt         []
# 131     MuddyWater_Middle_East_and_Central_Asia.pdf.txt         []
# 134     MuddyWater_Middle_East_and_Central_Asia.pdf.txt         []
# 135     MuddyWater_Middle_East_and_Central_Asia.pdf.txt         []
# ...                                                 ...        ...
# 657633                        chinas-electronic.pdf.txt         []
# 657639                        chinas-electronic.pdf.txt         []
# 657665                          army-bans-usb-d.pdf.txt         []
# 657717                          army-bans-usb-d.pdf.txt         []
# 657718                          army-bans-usb-d.pdf.txt         []
#
#        software_name  technique_name                    tactic  \
# 51                []  ['powershell']                        []
# 128               []              []  ['privilege escalation']
# 131               []  ['powershell']                        []
# 134               []  ['powershell']                        []
# 135               []              []           ['persistence']
# ...              ...             ...                       ...
# 657633      ['page']              []                        []
# 657639            []      ['source']                        []
# 657665            []              []             ['discovery']
# 657717            []              []            ['collection']
# 657718            []              []            ['collection']
#
#         energetic bear  chinastrats  ...  defense evasion  collection  \
# 51               False        False  ...            False       False
# 128              False        False  ...            False       False
# 131              False        False  ...            False       False
# 134              False        False  ...            False       False
# 135              False        False  ...            False       False
# ...                ...          ...  ...              ...         ...
# 657633           False        False  ...            False       False
# 657639           False        False  ...            False       False
# 657665           False        False  ...            False       False
# 657717           False        False  ...            False        True
# 657718           False        False  ...            False        True
#
#         credential access  execution  lateral movement  discovery  \
# 51                  False      False             False      False
# 128                 False      False             False      False
# 131                 False      False             False      False
# 134                 False      False             False      False
# 135                 False      False             False      False
# ...                   ...        ...               ...        ...
# 657633              False      False             False      False
# 657639              False      False             False      False
# 657665              False      False             False       True
# 657717              False      False             False      False
# 657718              False      False             False      False
#
#         command and control  persistence  exfiltration  privilege escalation
# 51                    False        False         False                 False
# 128                   False        False         False                  True
# 131                   False        False         False                 False
# 134                   False        False         False                 False
# 135                   False         True         False                 False
# ...                     ...          ...           ...                   ...
# 657633                False        False         False                 False
# 657639                False        False         False                 False
# 657665                False        False         False                 False
# 657717                False        False         False                 False
# 657718                False        False         False                 False
#
# [42393 rows x 475 columns]

# %%
def count_entity_values(verbose_index_df, entity_type):
    value_counter = dict()
    for name in mitre_labels[entity_type]:
        value_counter[name] = [verbose_index_df[name].sum()]

    with pd.option_context('display.max_rows', 500, 'display.max_columns', 10):
        df = pd.DataFrame(value_counter).transpose()
        print(df.shape)
        df.index.name = entity_type
        df.columns = ["count"]
        display(df)

# %%
count_entity_values(verbose_index_df, entity_type='group_name')
# Out:
# (112, 1)
#                     count
# group_name
# energetic bear         57
# chinastrats             4
# gamaredon group       136
# hidden cobra           74
# monsoon                83
# fancy bear            112
# stone panda            39
# buckeye                71
# threat group-1314       0
# poseidon group         23
# webmasters             12
# equation              312
# threat group-3390       6
# molerats               70
# lotus blossom         116
# deputy dog              9
# gcman                   8
# carbanak                0
# deep panda            193
# dragonok               77
# strider                19
# shell crew              5
# pittytiger             51
# oilrig                151
# ixeshe                  0
# cvnx                    8
# projectsauron           0
# apt10                 444
# emissary panda         64
# msupdater               8
# apt17                  47
# blackfly               11
# tg-3390               183
# turla                 978
# the dukes             265
# winnti group          213
# fin7                  205
# moafee                 33
# apt3                  517
# night dragon           99
# apt16                  14
# kungfu kittens          5
# black vine            108
# apt32                 119
# oceanlotus group       28
# dropping elephant      31
# tg-2889                 6
# guardians of peace     11
# rtm                     0
# apt1                 1154
# putter panda           59
# group5                164
# strontium              26
# red apollo              7
# apt2                  595
# comment group           7
# dynamite panda          5
# quedagh                50
# darkhotel             107
# admin@338              71
# numbered panda         28
# operation molerats      5
# taidoor               270
# naikon                360
# cleaver               168
# threat group-0416       0
# comment panda          12
# fin6                   44
# menupass              285
# ups team                5
# axiom                 107
# cozy bear              32
# pirpi                   0
# ke3chang              200
# scarlet mimic          76
# fin10                   4
# threat group-0110       1
# dragonfly             125
# dust storm             29
# operation hangover    188
# gothic panda           24
# tg-4127                 2
# sandworm team          26
# tg-0110                 5
# pinkpanther             3
# dyncalc                14
# waterbug              211
# sednit                491
# tsar team              12
# apt18                  32
# gaza cybergang         74
# apt12                  68
# apt29                 134
# pawn storm            204
# stealth falcon         21
# tg-1314                 0
# spring dragon           8
# anunak                  0
# apt30                 209
# suckfly                27
# patchwork             158
# threat group 2889       1
# threat group-4127       1
# lazarus group         467
# comment crew           66
# sofacy                353
# group 72               24
# apt28                 471
# bronze union           50
# tg-0416                 2
# ncph                    0
# wicked rose             0

# %%
count_entity_values(verbose_index_df, entity_type='software_name')
# Out:
# (183, 1)
#                                 count
# software_name
# hammerduke                         32
# nbtstat.exe                         0
# ned worm                           19
# xtunnel                           101
# sys10                              19
# hcdloader                           1
# enfal                              47
# elmer                              14
# miniduke                          367
# mobileorder                        14
# systeminfo.exe                      9
# ixeshe                              0
# arp                                56
# windows credential editor          15
# netsh                              60
# cmd.exe                           624
# spaceship                          45
# tinyzbot                           65
# owaauth                            17
# lecna                               6
# derusbi                           257
# arp.exe                             0
# hammertoss                         83
# winmm                              36
# coreshell                          59
# hdoor                              17
# komplex                            67
# gh0st                             670
# win32/usbstealer                    0
# powerduke                           8
# trojan.gtalk                        0
# chopstick                          86
# pisloader                          19
# custom hdoor                        8
# hidedrv                            23
# cozyduke                          263
# pinchduke                          68
# psylo                              22
# misdat                             25
# xcmd                                1
# evilgrab                           72
# sourface                           57
# glooxmail                           3
# psexec                            172
# snugride                            1
# netui                               5
# shipshape                          41
# carbanak                            0
# usb stealer                         3
# viper                              80
# sasfis                              1
# remsec                             41
# projectsauron                       0
# aspxspy                            29
# calendar                           56
# backdoor.oldrea                     0
# backspace                         273
# nidiran                            16
# reg                               228
# mivast                             13
# cozycar                            11
# schtasks.exe                       25
# biscuit                            12
# s-type                              0
# net                               941
# seadesk                             0
# ftp.exe                             6
# unknown logger                     22
# textmate                            1
# sakula                            147
# netsh.exe                           0
# tinybaron                           3
# scorpion                            8
# advstoreshell                       5
# elise                             126
# cachedump                           2
# trojan.karagany                     0
# token control                       0
# xagentosx                           1
# pwdump                             41
# powersource                         3
# epic                               68
# bugjuice                            0
# schtasks                          104
# halfbaked                           4
# pteranodon                         15
# tasklist                           70
# riptide                            30
# redleaves                          56
# neteagle                           52
# emissary                          362
# reg.exe                            11
# minidionis                         26
# rtm                                 0
# 3para rat                          18
# httpclient                         18
# systeminfo                         82
# backdoor.nidiran                    0
# onionduke                         129
# cloudlook                           6
# soundbite                           6
# ipconfig.exe                        8
# nbtstat                            11
# jhuhugit                           12
# cmd                               997
# backdoor.apt.cookiecutter           0
# backdoor.remsec                     0
# httpbrowser                       150
# pngdowner                          15
# uroburos                          149
# streamex                            2
# blackcoffee                        19
# wce                                30
# usbstealer                         17
# splm                               61
# netstat                            93
# seadaddy                            7
# netc                                4
# komprogo                           10
# lurid                              56
# bubblewrap                          6
# windshield                         21
# pirpi                               0
# poisonivy                          61
# ping.exe                            8
# poison ivy                        481
# httpdump                            6
# plugx                             838
# kaba                               20
# sslmm                              27
# winnti                            727
# haymaker                            0
# seduploader                       132
# cosmicduke                        171
# geminiduke                         42
# comrat                            139
# seaduke                            93
# autoit                            134
# mis-type                            0
# chches                             80
# zlib                              185
# sogu                               52
# aspxtool                            4
# lowball                             9
# dustysky                           65
# mimikatz                          448
# black energy                       11
# fakem                             151
# 4h rat                             14
# callme                              9
# china chopper                     230
# webc2                              43
# net.exe                            23
# poshspy                             2
# flashflood                         40
# xaps                                4
# gsecdump                           38
# blackenergy                       547
# ping                              200
# backdoor.apt.fakewinhttphelper      0
# netstat.exe                         9
# x-tunnel                            0
# rarstone                           15
# sakurel                            30
# oldbait                            11
# shotput                             9
# tavdig                             35
# anunak                              0
# cloudduke                          90
# lslsass                             9
# ftp                               373
# ipconfig                           96
# dnsmessenger                       13
# hikit                              92
# tinytyphon                         18
# badnews                            76
# phoreal                             5
# bkdr_esile                          3
# cobalt strike                     678
# pass-the-hash toolkit               0
# net crawler                        14
# netduke                             1
# havex                             153

# %%
count_entity_values(verbose_index_df, entity_type='technique_name')
# Out:
# (168, 1)
#                                                     count
# technique_name
# code signing                                          157
# access token manipulation                               8
# re-opened applications                                  0
# shortcut modification                                   7
# service registry permissions weakness                   0
# pass the ticket                                         5
# input prompt                                            2
# execution through module load                           8
# network sniffing                                        8
# registry run keys / start folder                        1
# pass the hash                                          25
# application shimming                                    2
# office application startup                              5
# file system permissions weakness                        0
# clear command history                                   4
# windows management instrumentation event subscr...      1
# connection proxy                                       27
# cron job                                                0
# component firmware                                      4
# network share connection removal                        0
# security support provider                              14
# fallback channels                                      14
# login item                                              4
# masquerading                                          151
# obfuscated files or information                        31
# commonly used port                                     45
# netsh helper dll                                        2
# system time discovery                                  17
# remote file copy                                       29
# screen capture                                        106
# hypervisor                                             22
# remote system discovery                                15
# sudo                                                    8
# standard application layer protocol                    16
# web shell                                             336
# third-party software                                    0
# data from network shared drive                          6
# system network configuration discovery                  8
# video capture                                          18
# rc.common                                               1
# .bash_profile and .bashrc                               1
# data encrypted                                         38
# data from local system                                 31
# windows admin shares                                   11
# system firmware                                         5
# application deployment software                         0
# appinit dlls                                            2
# credentials in files                                   12
# multiband communication                                 1
# brute force                                            88
# scripting                                             171
# powershell                                           1543
# dll injection                                          30
# custom command and control protocol                     6
# input capture                                          31
# file system logical offsets                             1
# scheduled transfer                                      6
# exfiltration over physical medium                       0
# uncommonly used port                                   11
# logon scripts                                           6
# bootkit                                               191
# startup items                                           7
# file and directory discovery                           26
# exfiltration over alternative protocol                  3
# hidden users                                            1
# remote desktop protocol                                51
# plist modification                                      3
# audio capture                                          17
# launch daemon                                           4
# automated exfiltration                                 12
# command-line interface                                  0
# external remote services                               11
# rundll32                                               98
# web service                                            35
# file deletion                                          53
# dll side-loading                                        0
# ntfs extended attributes                                3
# account discovery                                      36
# network service scanning                               15
# gatekeeper bypass                                       1
# remote services                                        52
# hidden window                                          26
# replication through removable media                     1
# hidden files and directories                           12
# trusted developer utilities                             2
# email collection                                       13
# exploitation of vulnerability                           1
# two-factor authentication interception                  0
# valid accounts                                         50
# timestomp                                              30
# data staged                                            21
# system service discovery                               11
# standard cryptographic protocol                        12
# new service                                           106
# disabling security tools                                9
# rootkit                                               621
# custom cryptographic protocol                           7
# exfiltration over command and control channel           6
# lc_main hijacking                                       1
# application window discovery                            4
# install root certificate                                2
# applescript                                             2
# winlogon helper dll                                     2
# exfiltration over other network medium                  0
# indicator removal from tools                            5
# lc_load_dylib addition                                  0
# data from removable media                               6
# service execution                                      29
# modify registry                                        36
# account manipulation                                   13
# communication through removable media                   1
# security software discovery                            12
# binary padding                                         13
# data compressed                                        19
# windows remote management                               5
# software packing                                       18
# multi-stage channels                                    0
# local port monitor                                      1
# data encoding                                          31
# dll search order hijacking                             27
# create account                                         12
# data transfer size limits                               3
# shared webroot                                          2
# component object model hijacking                        1
# installutil                                            17
# system information discovery                           29
# authentication package                                  4
# regsvr32                                               51
# space after filename                                    2
# change default file association                         3
# peripheral device discovery                             7
# clipboard data                                         47
# launchctl                                              14
# dylib hijacking                                         2
# query registry                                         26
# system owner/user discovery                             0
# path interception                                       6
# process discovery                                      38
# standard non-application layer protocol                 0
# multilayer encryption                                   7
# regsvcs/regasm                                          0
# launch agent                                            2
# permission groups discovery                             9
# histcontrol                                             1
# graphical user interface                               28
# scheduled task                                        291
# windows management instrumentation                     48
# process hollowing                                      31
# system network connections discovery                    9
# accessibility features                                 11
# modify existing service                                 4
# data obfuscation                                       17
# automated collection                                   19
# securityd memory                                        1
# private keys                                           33
# deobfuscate/decode files or information                 0
# execution through api                                  19
# indicator removal on host                              24
# network share discovery                                16
# indicator blocking                                      3
# trap                                                   38
# bypass user account control                            22
# taint shared content                                    4
# keychain                                                8
# setuid and setgid                                       2
# redundant access                                       15
# credential dumping                                     66
# bash history                                            1

# %%
count_entity_values(verbose_index_df, entity_type='tactic')
# Out:
# (10, 1)
#                       count
# tactic
# defense evasion          63
# collection              617
# credential access        47
# execution              2643
# lateral movement        429
# discovery               943
# command and control    1579
# persistence            1488
# exfiltration            657
# privilege escalation    214
